# %%
import pandas as pd
import numpy as np
df = pd.read_csv('A_stat_data_112a.csv')
df0 = df.copy()
df2 = df.copy()
df.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                  112.0            112-2
# 1           連續                  112.0            112-2
# 2           連續                  112.0            112-2
# 3          非連續                  112.0            112-2
# 4        連續＋圖表                  112.0            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3  Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4  Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                   0.0                             NaN
# 1                 NaN                   0.0                             NaN
# 2                 NaN                   0.0                             NaN
# 3                 NaN                   0.0                             NaN
# 4                 NaN                   0.0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
# 3                 NaN -6.293485e+18  2.406214e+17
# 4                 NaN  4.998280e+18 -3.340858e+18
#
# [5 rows x 22 columns]

# %%
df.tail(3)
# Out:
#         grade                    mission_name mission_difficulty  \
# 116491      8  04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
# 116492      8         04/11 仲裁【法治教育－法律程序】（中階）                  難
# 116493      8  04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
#
#        mission_field mission_type  mission_semester_year mission_semester  \
# 116491            議題           連續                    112            112-2
# 116492            議題           連續                    112            112-2
# 116493            議題           連續                    112            112-2
#
#                mission_datetime_utc8 mission_status  is_completed  ...  \
# 116491  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116492  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116493  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
#
#        answer_duration_sec  mission_answer_count  \
# 116491                 NaN                     0
# 116492                 NaN                     0
# 116493                 NaN                     0
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 116491                             NaN                                   NaN
# 116492                             NaN                                   NaN
# 116493                             NaN                                   NaN
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 116491                                 NaN                                NaN
# 116492                                 NaN                                NaN
# 116493                                 NaN                                NaN
#
#         form_indicator_correct_rate  first_correct_rate              user_id  \
# 116491                          NaN                 NaN  4579010491507678242
# 116492                          NaN                 NaN  4579010491507678242
# 116493                          NaN                 NaN          -5787857366
#
#           mission_id
# 116491 -4.474627e+18
# 116492  9.918571e+17
# 116493           NaN
#
# [3 rows x 22 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=116494, step=1)

# %%
df.columns
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %%
a = df2.columns
a_series = a.to_series()
print(a_series)
a_series.to_csv('work1.csv',index=False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# answer_duration_sec                                      answer_duration_sec
# mission_answer_count                                    mission_answer_count
# content_indicator_correct_rate                content_indicator_correct_rate
# comprehensive_indicator_correct_rate    comprehensive_indicator_correct_rate
# explanation_indicator_correct_rate        explanation_indicator_correct_rate
# extraction_indicator_correct_rate          extraction_indicator_correct_rate
# form_indicator_correct_rate                      form_indicator_correct_rate
# first_correct_rate                                        first_correct_rate
# user_id                                                              user_id
# mission_id                                                        mission_id
# dtype: object

# %%
df.describe()
# Out:
#                grade  mission_semester_year   is_completed  correct_rate  \
# count  116494.000000               116494.0  116494.000000  28491.000000
# mean        5.702886                  112.0       0.244571      0.407096
# std         1.515919                    0.0       0.429834      0.318091
# min         4.000000                  112.0       0.000000      0.000000
# 25%         4.000000                  112.0       0.000000      0.200000
# 50%         5.000000                  112.0       0.000000      0.400000
# 75%         6.000000                  112.0       0.000000      0.600000
# max         9.000000                  112.0       1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count         28422.000000         116494.000000
# mean            147.081979              0.743506
# std             341.402847              1.732222
# min               1.000000              0.000000
# 25%              10.000000              0.000000
# 50%              34.000000              0.000000
# 75%             170.000000              1.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                     6492.000000                          28180.000000
# mean                         0.373537                              0.411355
# std                          0.474374                              0.400447
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.750000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                        24695.000000                       25808.000000
# mean                             0.377684                           0.431765
# std                              0.446030                           0.453659
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                  4913.000000        29676.000000  1.164940e+05
# mean                      0.368512            0.451045 -3.393824e+16
# std                       0.480177            0.317308  5.350866e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.657114e+18
# 50%                       0.000000            0.400000  7.879954e+16
# 75%                       1.000000            0.600000  4.524190e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.164930e+05
# mean  -9.356490e+16
# std    5.285873e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.294306e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %%
b = df2.describe()
print(b)
b.to_excel('work2.xlsx')
# Out:
#                grade  mission_semester_year   is_completed  correct_rate  \
# count  116494.000000               116494.0  116494.000000  28491.000000
# mean        5.702886                  112.0       0.244571      0.407096
# std         1.515919                    0.0       0.429834      0.318091
# min         4.000000                  112.0       0.000000      0.000000
# 25%         4.000000                  112.0       0.000000      0.200000
# 50%         5.000000                  112.0       0.000000      0.400000
# 75%         6.000000                  112.0       0.000000      0.600000
# max         9.000000                  112.0       1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count         28422.000000         116494.000000
# mean            147.081979              0.743506
# std             341.402847              1.732222
# min               1.000000              0.000000
# 25%              10.000000              0.000000
# 50%              34.000000              0.000000
# 75%             170.000000              1.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                     6492.000000                          28180.000000
# mean                         0.373537                              0.411355
# std                          0.474374                              0.400447
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.750000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                        24695.000000                       25808.000000
# mean                             0.377684                           0.431765
# std                              0.446030                           0.453659
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                  4913.000000        29676.000000  1.164940e+05
# mean                      0.368512            0.451045 -3.393824e+16
# std                       0.480177            0.317308  5.350866e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.657114e+18
# 50%                       0.000000            0.400000  7.879954e+16
# 75%                       1.000000            0.600000  4.524190e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.164930e+05
# mean  -9.356490e+16
# std    5.285873e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.294306e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %%
c = df.sort_index(axis=1,ascending=False)
d = c.describe()
print(d)
d.to_excel('work3.xlsx')
d.to_csv('work4.csv',index=False)
# Out:
#             user_id  mission_semester_year    mission_id  \
# count  1.164940e+05               116494.0  1.164930e+05
# mean  -3.393824e+16                  112.0 -9.356490e+16
# std    5.350866e+18                    0.0  5.285873e+18
# min   -9.223321e+18                  112.0 -9.144214e+18
# 25%   -4.657114e+18                  112.0 -4.632199e+18
# 50%    7.879954e+16                  112.0 -1.294306e+17
# 75%    4.524190e+18                  112.0  3.909487e+18
# max    9.218903e+18                  112.0  9.217426e+18
#
#        mission_answer_count   is_completed          grade  \
# count         116494.000000  116494.000000  116494.000000
# mean               0.743506       0.244571       5.702886
# std                1.732222       0.429834       1.515919
# min                0.000000       0.000000       4.000000
# 25%                0.000000       0.000000       4.000000
# 50%                0.000000       0.000000       5.000000
# 75%                1.000000       0.000000       6.000000
# max               74.000000       1.000000       9.000000
#
#        form_indicator_correct_rate  first_correct_rate  \
# count                  4913.000000        29676.000000
# mean                      0.368512            0.451045
# std                       0.480177            0.317308
# min                       0.000000            0.000000
# 25%                       0.000000            0.200000
# 50%                       0.000000            0.400000
# 75%                       1.000000            0.600000
# max                       1.000000            1.000000
#
#        extraction_indicator_correct_rate  explanation_indicator_correct_rate  \
# count                       25808.000000                        24695.000000
# mean                            0.431765                            0.377684
# std                             0.453659                            0.446030
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.333333                            0.000000
# 75%                             1.000000                            1.000000
# max                             1.000000                            1.000000
#
#        correct_rate  content_indicator_correct_rate  \
# count  28491.000000                     6492.000000
# mean       0.407096                        0.373537
# std        0.318091                        0.474374
# min        0.000000                        0.000000
# 25%        0.200000                        0.000000
# 50%        0.400000                        0.000000
# 75%        0.600000                        1.000000
# max        1.000000                        1.000000
#
#        comprehensive_indicator_correct_rate  answer_duration_sec
# count                          28180.000000         28422.000000
# mean                               0.411355           147.081979
# std                                0.400447           341.402847
# min                                0.000000             1.000000
# 25%                                0.000000            10.000000
# 50%                                0.333333            34.000000
# 75%                                0.750000           170.000000
# max                                1.000000          3600.000000

# %%
print(df.columns)
x = df["grade"]
y = x[0:3]

y.to_excel('work5.xlsx')
y.to_csv('work6.csv',index=False)
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %%
#查詢重複值的個數
a="grade"
df2.duplicated(subset=[a]).sum()
# Out:
# 116488

# %%
duplication = df2[df2.duplicated(a)]
duplication[a]
# Out:
# 1         5
# 3         5
# 4         6
# 5         6
# 6         5
#          ..
# 116489    7
# 116490    7
# 116491    8
# 116492    8
# 116493    8
# Name: grade, Length: 116488, dtype: int64

# %%
a = 'user_id'
df3 = df2.drop_duplicates(a)
df3
# Out:
#         grade                                       mission_name  \
# 0           5                         05/06 虎姑婆【多元文化教育－傳說故事】（初階）
# 1           5                          05/06 二郎【多元文化教育－傳說故事】（初階）
# 2           6                          05/09 蚩尤【多元文化教育－傳說故事】（初階）
# 3           5                         05/13 狗狗吃便便【環境教育－動物奇聞】（初階）
# 4           6                   05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）
# ...       ...                                                ...
# 116355      9                      04/01 古人辦案科學嗎？【法治教育－法治素養】（中階）
# 116393      8  04/04 頭戴假髮、身穿黑袍、手持法槌──法官的黑袍文化從何而來？【法治教育－法治素養】（中階）
# 116399      9                     04/04 美國大法官金斯伯格【法治教育－法治素養】（中階）
# 116442      7                          04/08 存證信函【法治教育－法律程序】（中階）
# 116493      8                     04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）
#
#        mission_difficulty mission_field mission_type  mission_semester_year  \
# 0                       易            文學           連續                    112
# 1                       中            文學           連續                    112
# 2                       難            人物           連續                    112
# 3                       中          生活知識          非連續                    112
# 4                       易          自然科學        連續＋圖表                    112
# ...                   ...           ...          ...                    ...
# 116355                  中          自然科學           連續                    112
# 116393                  中            文化           連續                    112
# 116399                  難            人物           連續                    112
# 116442                  中          生活知識           連續                    112
# 116493                  難            議題           連續                    112
#
#        mission_semester         mission_datetime_utc8 mission_status  \
# 0                 112-2  Mon May 06 08:00:00 UTC 2024          已派發任務
# 1                 112-2  Mon May 06 08:00:00 UTC 2024          已派發任務
# 2                 112-2  Thu May 09 08:00:00 UTC 2024          已派發任務
# 3                 112-2  Mon May 13 08:00:00 UTC 2024          已派發任務
# 4                 112-2  Thu May 16 08:00:00 UTC 2024          已派發任務
# ...                 ...                           ...            ...
# 116355            112-2  Mon Apr 01 08:00:00 UTC 2024           完成任務
# 116393            112-2  Thu Apr 04 08:00:00 UTC 2024          已派發任務
# 116399            112-2  Thu Apr 04 08:00:00 UTC 2024          已派發任務
# 116442            112-2  Mon Apr 08 08:00:00 UTC 2024          已派發任務
# 116493            112-2  Thu Apr 11 08:00:00 UTC 2024          已派發任務
#
#         is_completed  ... answer_duration_sec  mission_answer_count  \
# 0                  0  ...                 NaN                     0
# 1                  0  ...                 NaN                     0
# 2                  0  ...                 NaN                     0
# 3                  0  ...                 NaN                     0
# 4                  0  ...                 NaN                     0
# ...              ...  ...                 ...                   ...
# 116355             1  ...               262.0                     3
# 116393             0  ...                 NaN                     0
# 116399             0  ...                 NaN                     0
# 116442             0  ...                 NaN                     0
# 116493             0  ...                 NaN                     0
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# ...                                ...                                   ...
# 116355                             NaN                                   0.0
# 116393                             NaN                                   NaN
# 116399                             NaN                                   NaN
# 116442                             NaN                                   NaN
# 116493                             NaN                                   NaN
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 116355                                 NaN                                1.0
# 116393                                 NaN                                NaN
# 116399                                 NaN                                NaN
# 116442                                 NaN                                NaN
# 116493                                 NaN                                NaN
#
#         form_indicator_correct_rate  first_correct_rate              user_id  \
# 0                               NaN                 NaN -8373966078912715601
# 1                               NaN                 NaN  3516683932418412104
# 2                               NaN                 NaN   -65799051578279613
# 3                               NaN                 NaN -6293485111595748020
# 4                               NaN                 NaN  4998280410504838977
# ...                             ...                 ...                  ...
# 116355                          NaN                 0.6  7298445580460230289
# 116393                          NaN                 NaN  2467043115252712340
# 116399                          NaN                 NaN -3701700767496435749
# 116442                          NaN                 NaN -8226245468390815330
# 116493                          NaN                 NaN          -5787857366
#
#           mission_id
# 0       8.154604e+18
# 1       3.762301e+18
# 2       4.652808e+18
# 3       2.406214e+17
# 4      -3.340858e+18
# ...              ...
# 116355 -8.644216e+18
# 116393  1.101648e+18
# 116399 -2.131450e+18
# 116442  1.461809e+18
# 116493           NaN
#
# [8858 rows x 22 columns]

# %%
p = 'one two one two one two'.split()
p1 = 'a1 a2 a3 a4 a5 a6'.split()
df = pd.DataFrame(
    {
        "A": p,
        "B": p1,
        "C": np.random.randn(6),
        "D": np.random.randn(6),
    }
)
df
# Out:
#      A   B         C         D
# 0  one  a1  0.947180  2.067647
# 1  two  a2 -0.494029 -1.576498
# 2  one  a3 -0.344359 -0.382805
# 3  two  a4 -1.364596  0.586458
# 4  one  a5 -0.700734 -0.055292
# 5  two  a6 -0.155055  0.326505

# %%
df.groupby("A").sum()
# Out:
#           B         C         D
# A
# one  a1a3a5 -0.097913  1.629550
# two  a2a4a6 -2.013680 -0.663535

# %%
df.groupby(["A","B"]).sum()
# Out:
#                C         D
# A   B
# one a1  0.947180  2.067647
#     a3 -0.344359 -0.382805
#     a5 -0.700734 -0.055292
# two a2 -0.494029 -1.576498
#     a4 -1.364596  0.586458
#     a6 -0.155055  0.326505

# %%
stack = df.stack()
stack
# Out:
# 0  A         one
#    B          a1
#    C     0.94718
#    D    2.067647
# 1  A         two
#    B          a2
#    C   -0.494029
#    D   -1.576498
# 2  A         one
#    B          a3
#    C   -0.344359
#    D   -0.382805
# 3  A         two
#    B          a4
#    C   -1.364596
#    D    0.586458
# 4  A         one
#    B          a5
#    C   -0.700734
#    D   -0.055292
# 5  A         two
#    B          a6
#    C   -0.155055
#    D    0.326505
# dtype: object

# %%
a = df2.columns
pp2 = []
for j in a:
    try:
        print(df2[j].groupby(df2[j]).count())
        pp2.append(df2[j].groupby(df2[j]).count())
    except:
        print("KeyError")
# Out:
# grade
# 4    29897
# 5    30752
# 6    27158
# 7    10049
# 8    10029
# 9     8609
# Name: grade, dtype: int64
# mission_name
# 01/01 我們是用戶還是商品？社群媒體之戰【資訊教育－社群媒體】(中階)     172
# 01/01 數據風暴【資訊教育－社群媒體】(中階)                 171
# 01/01 表情符號【資訊教育－資訊解讀】(初階)                 468
# 01/01 觀影資訊【資訊教育－資訊解讀】(初階)                 450
# 01/04 你可能已經犯罪了！【資訊教育－數位倫理】(中階)            180
#                                          ...
# 5月特別任務－【SDGs 議題】（初階）                      620
# 6月特別任務－【SDGs 議題】（中階）                      162
# 6月特別任務－【SDGs 議題】（初階）                      600
# 9月特別任務－【SDGs 議題】（中階）                      540
# 9月特別任務－【SDGs 議題】（初階）                     1502
# Name: mission_name, Length: 335, dtype: int64
# mission_difficulty
# 中    63259
# 易    30522
# 難    17170
# Name: mission_difficulty, dtype: int64
# mission_field
# 世界櫥窗    13415
# 人文史地     9232
# 人物       5099
# 文化       9301
# 文學       5406
# 生活知識    28673
# 社會科學     5536
# 自然科學    12699
# 說明文件     4842
# 議題      16748
# Name: mission_field, dtype: int64
# mission_type
# 連續       61731
# 連續＋圖表    14221
# 非連續      34999
# Name: mission_type, dtype: int64
# mission_semester_year
# 112    116494
# Name: mission_semester_year, dtype: int64
# mission_semester
# 112-1    57923
# 112-2    58571
# Name: mission_semester, dtype: int64
# mission_datetime_utc8
# Fri Dec 22 08:00:00 UTC 2023     661
# Fri Mar 22 08:00:00 UTC 2024     663
# Fri Sep 22 08:00:00 UTC 2023    2042
# Mon Apr 01 08:00:00 UTC 2024    1419
# Mon Apr 08 08:00:00 UTC 2024    1324
#                                 ...
# Thu Sep 14 08:00:00 UTC 2023    1387
# Thu Sep 21 08:00:00 UTC 2023    1404
# Thu Sep 28 08:00:00 UTC 2023    1347
# Wed May 22 08:00:00 UTC 2024     760
# Wed Nov 22 08:00:00 UTC 2023     647
# Name: mission_datetime_utc8, Length: 86, dtype: int64
# mission_status
# 取消派發       118
# 完成任務     28438
# 已派發任務    84936
# 暫停任務      2584
# 進行任務中      418
# Name: mission_status, dtype: int64
# is_completed
# 0    88003
# 1    28491
# Name: is_completed, dtype: int64
# completed_at_utc8
# Fri Apr 05 07:55:32 UTC 2024    1
# Fri Apr 05 08:06:45 UTC 2024    1
# Fri Apr 05 08:54:13 UTC 2024    1
# Fri Apr 05 09:26:36 UTC 2024    1
# Fri Apr 05 12:44:59 UTC 2024    1
#                                ..
# Wed Sep 27 17:19:19 UTC 2023    1
# Wed Sep 27 17:31:23 UTC 2023    1
# Wed Sep 27 20:13:37 UTC 2023    1
# Wed Sep 27 21:17:47 UTC 2023    1
# Wed Sep 27 21:32:59 UTC 2023    1
# Name: completed_at_utc8, Length: 27973, dtype: int64
# correct_rate
# 0.000000    5216
# 0.066667     108
# 0.133333     205
# 0.166667       1
# 0.200000    6746
# 0.266667     255
# 0.333333     193
# 0.400000    5998
# 0.466667      77
# 0.533333      37
# 0.600000    3720
# 0.666667      16
# 0.733333      11
# 0.800000    2650
# 0.866667       8
# 0.933333       3
# 1.000000    3247
# Name: correct_rate, dtype: int64
# answer_duration_sec
# 1.0         17
# 2.0         72
# 3.0        309
# 4.0        728
# 5.0       1139
#           ...
# 3289.0       1
# 3341.0       1
# 3450.0       1
# 3599.0       3
# 3600.0     166
# Name: answer_duration_sec, Length: 1122, dtype: int64
# mission_answer_count
# 0     85965
# 1      6620
# 2     11695
# 3      5524
# 4      2665
# 5      1434
# 6       861
# 7       524
# 8       349
# 9       239
# 10      153
# 11      109
# 12       94
# 13       68
# 14       42
# 15       29
# 16       29
# 17       17
# 18       13
# 19       10
# 20        7
# 21       10
# 22        3
# 23        3
# 24        6
# 25        2
# 26        2
# 27        1
# 28        2
# 29        2
# 30        2
# 31        2
# 32        2
# 34        2
# 36        2
# 37        1
# 39        1
# 42        1
# 43        1
# 51        1
# 74        1
# Name: mission_answer_count, dtype: int64
# content_indicator_correct_rate
# 0.0    3950
# 0.5     234
# 1.0    2308
# Name: content_indicator_correct_rate, dtype: int64
# comprehensive_indicator_correct_rate
# 0.000000    11183
# 0.111111       70
# 0.125000       49
# 0.142857      108
# 0.166667       11
# 0.200000       72
# 0.222222       79
# 0.250000      554
# 0.285714       85
# 0.333333     2420
# 0.375000       30
# 0.400000       54
# 0.428571       49
# 0.444444       41
# 0.500000     4525
# 0.555556       19
# 0.571429       20
# 0.600000       13
# 0.625000       10
# 0.666667     1595
# 0.714286       16
# 0.750000      233
# 0.777778        8
# 0.800000        7
# 0.857143        5
# 0.875000        2
# 0.888889        5
# 1.000000     6917
# Name: comprehensive_indicator_correct_rate, dtype: int64
# explanation_indicator_correct_rate
# 0.000000    13460
# 0.166667       55
# 0.200000        3
# 0.250000       52
# 0.333333      438
# 0.400000        7
# 0.500000     2904
# 0.600000        1
# 0.666667      209
# 0.750000        6
# 0.800000        3
# 0.833333        3
# 1.000000     7554
# Name: explanation_indicator_correct_rate, dtype: int64
# extraction_indicator_correct_rate
# 0.000000    12372
# 0.166667       55
# 0.200000      206
# 0.250000      128
# 0.333333      437
# 0.400000      117
# 0.500000     3025
# 0.600000       63
# 0.666667      225
# 0.750000       25
# 0.800000       27
# 0.833333        3
# 1.000000     9125
# Name: extraction_indicator_correct_rate, dtype: int64
# form_indicator_correct_rate
# 0.0    3081
# 0.5      43
# 1.0    1789
# Name: form_indicator_correct_rate, dtype: int64
# first_correct_rate
# 0.000000    3729
# 0.066667      69
# 0.133333     162
# 0.200000    7272
# 0.266667     223
# 0.333333     181
# 0.400000    6538
# 0.466667      73
# 0.533333      35
# 0.600000    4090
# 0.666667      16
# 0.733333      11
# 0.800000    3158
# 0.866667       8
# 0.933333       3
# 1.000000    4108
# Name: first_correct_rate, dtype: int64
# user_id
# -9223321156357508358    12
# -9222609255196723390     4
# -9221135146560186179    17
# -9218970229368107251     3
# -9218030684663223433    22
#                         ..
#  9208394452898253184    15
#  9212946253008955797    22
#  9215839480821721378     9
#  9216205039327361044     9
#  9218903231836064997     3
# Name: user_id, Length: 8858, dtype: int64
# mission_id
# -9.144214e+18    118
# -9.108400e+18    459
# -9.027191e+18    521
# -9.015410e+18    172
# -8.952441e+18    189
#                 ...
#  9.100905e+18    580
#  9.118853e+18    427
#  9.122208e+18    180
#  9.180295e+18    455
#  9.217426e+18    544
# Name: mission_id, Length: 339, dtype: int64

# %%
with open('timesTable_3.txt', 'w', encoding = 'utf-8') as f:
    f.write(str(pp2))
    f.close

# %%
df1 = df2.copy()
df1.dropna()
# Out:
#         grade               mission_name mission_difficulty mission_field  \
# 677         6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1333        4  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4975        5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4976        5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4977        5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# ...       ...                        ...                ...           ...
# 106319      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 106320      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 106652      4  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 111171      5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 111186      5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
#
#        mission_type  mission_semester_year mission_semester  \
# 677              連續                    112            112-1
# 1333             連續                    112            112-1
# 4975             連續                    112            112-1
# 4976             連續                    112            112-1
# 4977             連續                    112            112-1
# ...             ...                    ...              ...
# 106319           連續                    112            112-1
# 106320           連續                    112            112-1
# 106652           連續                    112            112-1
# 111171           連續                    112            112-1
# 111186           連續                    112            112-1
#
#                mission_datetime_utc8 mission_status  is_completed  ...  \
# 677     Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 1333    Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 4975    Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 4976    Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 4977    Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# ...                              ...            ...           ...  ...
# 106319  Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 106320  Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 106652  Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 111171  Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
# 111186  Thu Nov 16 08:00:00 UTC 2023           完成任務             1  ...
#
#        answer_duration_sec  mission_answer_count  \
# 677                    8.0                     2
# 1333                  49.0                     4
# 4975                   5.0                     2
# 4976                  15.0                     1
# 4977                   3.0                     3
# ...                    ...                   ...
# 106319               181.0                     1
# 106320               228.0                     3
# 106652                28.0                     1
# 111171                47.0                     3
# 111186                11.0                     7
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 677                                1.0                                   0.0
# 1333                               0.0                                   0.0
# 4975                               0.0                                   1.0
# 4976                               1.0                                   1.0
# 4977                               0.0                                   0.0
# ...                                ...                                   ...
# 106319                             1.0                                   1.0
# 106320                             1.0                                   1.0
# 106652                             1.0                                   1.0
# 111171                             1.0                                   0.0
# 111186                             0.0                                   0.0
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 677                                    0.0                                1.0
# 1333                                   1.0                                1.0
# 4975                                   0.0                                1.0
# 4976                                   1.0                                1.0
# 4977                                   0.0                                0.0
# ...                                    ...                                ...
# 106319                                 1.0                                1.0
# 106320                                 1.0                                0.0
# 106652                                 1.0                                1.0
# 111171                                 0.0                                1.0
# 111186                                 0.0                                1.0
#
#         form_indicator_correct_rate  first_correct_rate              user_id  \
# 677                             1.0                 0.6  4524907499274555771
# 1333                            0.0                 0.4  3879788643829841554
# 4975                            0.0                 0.4 -3519350230413345858
# 4976                            1.0                 1.0  8189606819013202011
# 4977                            0.0                 0.8 -1625213224247900614
# ...                             ...                 ...                  ...
# 106319                          1.0                 1.0 -8666798300779869511
# 106320                          1.0                 0.8  5191305292496831122
# 106652                          1.0                 1.0  -450132005562897315
# 111171                          0.0                 0.4 -5705177551638731645
# 111186                          0.0                 0.2 -3924211524648972796
#
#           mission_id
# 677    -3.755334e+18
# 1333   -3.755334e+18
# 4975   -3.755334e+18
# 4976   -3.755334e+18
# 4977   -3.755334e+18
# ...              ...
# 106319 -3.755334e+18
# 106320 -3.755334e+18
# 106652 -3.755334e+18
# 111171 -3.755334e+18
# 111186 -3.755334e+18
#
# [107 rows x 22 columns]

# %%
df1.fillna(5)
# Out:
#         grade                      mission_name mission_difficulty  \
# 0           5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1           5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2           6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3           5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4           6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...       ...                               ...                ...
# 116489      7           04/11 仲裁【法治教育－法律程序】（中階）                  難
# 116490      7    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
# 116491      8    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
# 116492      8           04/11 仲裁【法治教育－法律程序】（中階）                  難
# 116493      8    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
#
#        mission_field mission_type  mission_semester_year mission_semester  \
# 0                 文學           連續                    112            112-2
# 1                 文學           連續                    112            112-2
# 2                 人物           連續                    112            112-2
# 3               生活知識          非連續                    112            112-2
# 4               自然科學        連續＋圖表                    112            112-2
# ...              ...          ...                    ...              ...
# 116489            議題           連續                    112            112-2
# 116490            議題           連續                    112            112-2
# 116491            議題           連續                    112            112-2
# 116492            議題           連續                    112            112-2
# 116493            議題           連續                    112            112-2
#
#                mission_datetime_utc8 mission_status  is_completed  ...  \
# 0       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2       Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3       Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4       Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                              ...            ...           ...  ...
# 116489  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116490  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116491  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116492  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116493  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
#
#        answer_duration_sec  mission_answer_count  \
# 0                      5.0                     0
# 1                      5.0                     0
# 2                      5.0                     0
# 3                      5.0                     0
# 4                      5.0                     0
# ...                    ...                   ...
# 116489                 5.0                     0
# 116490                 5.0                     0
# 116491                 5.0                     0
# 116492                 5.0                     0
# 116493                 5.0                     0
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                  5.0                                   5.0
# 1                                  5.0                                   5.0
# 2                                  5.0                                   5.0
# 3                                  5.0                                   5.0
# 4                                  5.0                                   5.0
# ...                                ...                                   ...
# 116489                             5.0                                   5.0
# 116490                             5.0                                   5.0
# 116491                             5.0                                   5.0
# 116492                             5.0                                   5.0
# 116493                             5.0                                   5.0
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 0                                      5.0                                5.0
# 1                                      5.0                                5.0
# 2                                      5.0                                5.0
# 3                                      5.0                                5.0
# 4                                      5.0                                5.0
# ...                                    ...                                ...
# 116489                                 5.0                                5.0
# 116490                                 5.0                                5.0
# 116491                                 5.0                                5.0
# 116492                                 5.0                                5.0
# 116493                                 5.0                                5.0
#
#         form_indicator_correct_rate  first_correct_rate              user_id  \
# 0                               5.0                 5.0 -8373966078912715601
# 1                               5.0                 5.0  3516683932418412104
# 2                               5.0                 5.0   -65799051578279613
# 3                               5.0                 5.0 -6293485111595748020
# 4                               5.0                 5.0  4998280410504838977
# ...                             ...                 ...                  ...
# 116489                          5.0                 5.0  2020681536459045460
# 116490                          5.0                 5.0  2020681536459045460
# 116491                          5.0                 5.0  4579010491507678242
# 116492                          5.0                 5.0  4579010491507678242
# 116493                          5.0                 5.0          -5787857366
#
#           mission_id
# 0       8.154604e+18
# 1       3.762301e+18
# 2       4.652808e+18
# 3       2.406214e+17
# 4      -3.340858e+18
# ...              ...
# 116489  9.918571e+17
# 116490 -4.474627e+18
# 116491 -4.474627e+18
# 116492  9.918571e+17
# 116493  5.000000e+00
#
# [116494 rows x 22 columns]

# %%
df1.interpolate( )
#interpolate’s parameter: "ffill", "bfill", "pad", "backfill"
# Out:
# <ipython-input-25-7aa220a8e413>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1.interpolate( )
#         grade                      mission_name mission_difficulty  \
# 0           5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1           5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2           6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3           5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4           6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...       ...                               ...                ...
# 116489      7           04/11 仲裁【法治教育－法律程序】（中階）                  難
# 116490      7    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
# 116491      8    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
# 116492      8           04/11 仲裁【法治教育－法律程序】（中階）                  難
# 116493      8    04/11 交保就是無罪釋放？【法治教育－法律程序】（中階）                  難
#
#        mission_field mission_type  mission_semester_year mission_semester  \
# 0                 文學           連續                    112            112-2
# 1                 文學           連續                    112            112-2
# 2                 人物           連續                    112            112-2
# 3               生活知識          非連續                    112            112-2
# 4               自然科學        連續＋圖表                    112            112-2
# ...              ...          ...                    ...              ...
# 116489            議題           連續                    112            112-2
# 116490            議題           連續                    112            112-2
# 116491            議題           連續                    112            112-2
# 116492            議題           連續                    112            112-2
# 116493            議題           連續                    112            112-2
#
#                mission_datetime_utc8 mission_status  is_completed  ...  \
# 0       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2       Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3       Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4       Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                              ...            ...           ...  ...
# 116489  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116490  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116491  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116492  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
# 116493  Thu Apr 11 08:00:00 UTC 2024          已派發任務             0  ...
#
#        answer_duration_sec  mission_answer_count  \
# 0                      NaN                     0
# 1                      NaN                     0
# 2                      NaN                     0
# 3                      NaN                     0
# 4                      NaN                     0
# ...                    ...                   ...
# 116489                12.0                     0
# 116490                12.0                     0
# 116491                12.0                     0
# 116492                12.0                     0
# 116493                12.0                     0
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# ...                                ...                                   ...
# 116489                             1.0                                   0.0
# 116490                             1.0                                   0.0
# 116491                             1.0                                   0.0
# 116492                             1.0                                   0.0
# 116493                             1.0                                   0.0
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 116489                                 0.0                                0.0
# 116490                                 0.0                                0.0
# 116491                                 0.0                                0.0
# 116492                                 0.0                                0.0
# 116493                                 0.0                                0.0
#
#         form_indicator_correct_rate  first_correct_rate              user_id  \
# 0                               NaN                 NaN -8373966078912715601
# 1                               NaN                 NaN  3516683932418412104
# 2                               NaN                 NaN   -65799051578279613
# 3                               NaN                 NaN -6293485111595748020
# 4                               NaN                 NaN  4998280410504838977
# ...                             ...                 ...                  ...
# 116489                          1.0                 0.6  2020681536459045460
# 116490                          1.0                 0.6  2020681536459045460
# 116491                          1.0                 0.6  4579010491507678242
# 116492                          1.0                 0.6  4579010491507678242
# 116493                          1.0                 0.6          -5787857366
#
#           mission_id
# 0       8.154604e+18
# 1       3.762301e+18
# 2       4.652808e+18
# 3       2.406214e+17
# 4      -3.340858e+18
# ...              ...
# 116489  9.918571e+17
# 116490 -4.474627e+18
# 116491 -4.474627e+18
# 116492  9.918571e+17
# 116493  9.918571e+17
#
# [116494 rows x 22 columns]

# %%
df2.head(10000).to_excel('output_partial_data.xlsx', index=False)
print("成功將部分數據保存到 Excel 文件")
# Out:
# 成功將部分數據保存到 Excel 文件

# %%
df3 = df2.head(10000)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds,_=default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
gsheets=gc.open_by_url("https://docs.google.com/spreadsheets/d/1C2lhY7H43jK3st1qGBLyed33uGbE_54tcyOF8D6Vy8o/edit?usp=sharing")

# %%
from gspread_dataframe import set_with_dataframe
#select new sheets
worksheet = gsheets.get_worksheet(0)
#taking your DataFrame into Googlesheets
set_with_dataframe(worksheet,df3)

# %%
df1 = pd.DataFrame(
{
"A": ["A0", "A1", "A2", "A3"],"B": ["B0", "B1", "B2", "B3"], "C": ["C0", "C1", "C2", "C3"], "D": ["D0", "D1", "D2", "D3"],
},
index=[0, 1, 2, 3],
)
df2 = pd.DataFrame(
{
"A": ["A4", "A5", "A6", "A7"], "B": ["B4", "B5", "B6", "B7"], "C": ["C4", "C5", "C6", "C7"], "D": ["D4", "D5", "D6", "D7"],
},
index=[4, 5, 6, 7],
)
df3 = pd.DataFrame(
{
"A": ["A8", "A9", "A10", "A11"], "B": ["B8", "B9", "B10", "B11"], "C": ["C8", "C9", "C10", "C11"], "D": ["D8", "D9", "D10", "D11"],
},
index=[8, 9, 10, 11],)

# %%
frames = [df1, df2, df3]
result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame(
{
"B": ["B2", "B3", "B6", "B7"],
"D": ["D2", "D3", "D6", "D7"],
"F": ["F2", "F3", "F6", "F7"],
},
index=[2, 3, 6, 7],
)
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
left = pd.DataFrame({"key": ["A","B"], "lval": [1,2]})
print(left)
right = pd.DataFrame({"key": ["A","B"], "rval": [3,4]})
print(right)
pd.merge(right, left, on="key")
# Out:
#   key  lval
# 0   A     1
# 1   B     2
#   key  rval
# 0   A     3
# 1   B     4
#   key  rval  lval
# 0   A     3     1
# 1   B     4     2

# %%
gf= []
ww = df0['grade']
for i in range(len(ww)):
  i+= 1
  gf.append(i)
df4 = pd.DataFrame(gf)
df4
# Out:
#              0
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 194405  194406
# 194406  194407
# 194407  194408
# 194408  194409
# 194409  194410
#
# [194410 rows x 1 columns]
